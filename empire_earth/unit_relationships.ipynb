# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from IPython.display import display, HTML
import pandas
# import qgrid
import empire_earth.databases
import empire_earth.units.relationships.matrices

# %%
pandas.set_option("display.max_rows", 999)
pandas.set_option("display.max_columns", 999)
pandas.set_option('display.precision', 3)
# pandas.set_option("display.width", 2000)

# %%
# %%time
# empire_earth.databases.dbobjects()

# %%
# empire_earth.databases.dbfamily()

# %%
# empire_earth.databases.dbweapontohit()

# %%
# dbtechtree = empire_earth.databases.dbtechtree()
# dbtechtree = pandas.concat(dbtechtree.values())
# dbtechtree

# %%
def vertical_scroll(dataframe: pandas.DataFrame):
    return display(HTML("<div style='height: 500px; overflow: auto; width: fit-content'>" + dataframe.to_html() + "</div>"))

# %%
# units_all = empire_earth.units.all()

# %%
units = empire_earth.units.attackers()

# %%
units_paleo = [units[name] for name in units if units[name].is_available(11)]
# units_paleo.sort(key=lambda unit: unit.name)
units_paleo.sort(key=lambda unit: unit.attack / unit.seconds_per_attack)
# units_paleo.sort(key=lambda unit: unit.attack_mode)
# units_paleo.sort(key=lambda unit: unit.weapon_hit_id)
units_paleo.sort(key=lambda unit: unit.building_id)
units_paleo.sort(key=lambda unit: unit.type_id)
# units_paleo = {unit.id: unit for unit in units_paleo}
# vertical_scroll(pandas.DataFrame(units_paleo))

# %%
# import empire_earth.units.relationships
vertical_scroll(empire_earth.units.relationships.matrices.matrix_tactical(units_paleo).style.set_sticky('columns'))
# Out:
# <div style='height: 500px; overflow: auto; width: fit-content'><style type="text/css">
# #T_6499b thead tr:nth-child(1) th {
#   position: sticky;
#   background-color: white;
#   top: 0px;
#   z-index: 2;
#   height: 25px;
# }
# #T_6499b thead tr:nth-child(2) th {
#   position: sticky;
#   background-color: white;
#   top: 25px;
#   z-index: 2;
#   height: 25px;
# }
# </style>
# <table id="T_6499b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6499b_level0_col0" class="col_heading level0 col0" >88mm AA Gun</th>
#       <th id="T_6499b_level0_col1" class="col_heading level0 col1" >Tower - Concrete</th>
#       <th id="T_6499b_level0_col2" class="col_heading level0 col2" >Typhoon Anti-Tank</th>
#       <th id="T_6499b_level0_col3" class="col_heading level0 col3" >ME109  Fighter/Bomber</th>
#       <th id="T_6499b_level0_col4" class="col_heading level0 col4" >Spitfire Fighter</th>
#       <th id="T_6499b_level0_col5" class="col_heading level0 col5" >P-51 Fighter</th>
#       <th id="T_6499b_level0_col6" class="col_heading level0 col6" >ME262 Fighter/Bomber</th>
#       <th id="T_6499b_level0_col7" class="col_heading level0 col7" >Heinkel Bomber</th>
#       <th id="T_6499b_level0_col8" class="col_heading level0 col8" >B-17 Bomber</th>
#       <th id="T_6499b_level0_col9" class="col_heading level0 col9" >B-29 Bomber</th>
#       <th id="T_6499b_level0_col10" class="col_heading level0 col10" >Corsair Fighter/Bomber</th>
#       <th id="T_6499b_level0_col11" class="col_heading level0 col11" >Frigate - Warrington</th>
#       <th id="T_6499b_level0_col12" class="col_heading level0 col12" >Cruiser - Dardo</th>
#       <th id="T_6499b_level0_col13" class="col_heading level0 col13" >Battleship - Bismarck</th>
#       <th id="T_6499b_level0_col14" class="col_heading level0 col14" >Bazooka</th>
#       <th id="T_6499b_level0_col15" class="col_heading level0 col15" >Sniper</th>
#       <th id="T_6499b_level0_col16" class="col_heading level0 col16" >Trench Mortar</th>
#       <th id="T_6499b_level0_col17" class="col_heading level0 col17" >Flame Thrower</th>
#       <th id="T_6499b_level0_col18" class="col_heading level0 col18" >Machine Gun</th>
#       <th id="T_6499b_level0_col19" class="col_heading level0 col19" >Marine</th>
#       <th id="T_6499b_level0_col20" class="col_heading level0 col20" >SAS Commando</th>
#       <th id="T_6499b_level0_col21" class="col_heading level0 col21" >57mm AT Gun</th>
#       <th id="T_6499b_level0_col22" class="col_heading level0 col22" >Artillery</th>
#       <th id="T_6499b_level0_col23" class="col_heading level0 col23" >Howitzer Cannon</th>
#       <th id="T_6499b_level0_col24" class="col_heading level0 col24" >Flak Halftrack</th>
#       <th id="T_6499b_level0_col25" class="col_heading level0 col25" >Panzer Tank (AP)</th>
#       <th id="T_6499b_level0_col26" class="col_heading level0 col26" >Sherman Tank (HE)</th>
#       <th id="T_6499b_level0_col27" class="col_heading level0 col27" >Citizen</th>
#       <th id="T_6499b_level0_col28" class="col_heading level0 col28" >Sub - U-Boat</th>
#       <th id="T_6499b_level0_col29" class="col_heading level0 col29" >Erwin Rommel</th>
#       <th id="T_6499b_level0_col30" class="col_heading level0 col30" >Travis Shackelford</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Attacker</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#       <th class="blank col29" >&nbsp;</th>
#       <th class="blank col30" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6499b_level0_row0" class="row_heading level0 row0" >88mm AA Gun</th>
#       <td id="T_6499b_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_6499b_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_6499b_row0_col2" class="data row0 col2" >inf</td>
#       <td id="T_6499b_row0_col3" class="data row0 col3" >7.292173</td>
#       <td id="T_6499b_row0_col4" class="data row0 col4" >inf</td>
#       <td id="T_6499b_row0_col5" class="data row0 col5" >inf</td>
#       <td id="T_6499b_row0_col6" class="data row0 col6" >5.244755</td>
#       <td id="T_6499b_row0_col7" class="data row0 col7" >0.093750</td>
#       <td id="T_6499b_row0_col8" class="data row0 col8" >0.069444</td>
#       <td id="T_6499b_row0_col9" class="data row0 col9" >0.009091</td>
#       <td id="T_6499b_row0_col10" class="data row0 col10" >11.455279</td>
#       <td id="T_6499b_row0_col11" class="data row0 col11" >0.000000</td>
#       <td id="T_6499b_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_6499b_row0_col13" class="data row0 col13" >0.000000</td>
#       <td id="T_6499b_row0_col14" class="data row0 col14" >0.000000</td>
#       <td id="T_6499b_row0_col15" class="data row0 col15" >0.000000</td>
#       <td id="T_6499b_row0_col16" class="data row0 col16" >0.000000</td>
#       <td id="T_6499b_row0_col17" class="data row0 col17" >0.000000</td>
#       <td id="T_6499b_row0_col18" class="data row0 col18" >0.000000</td>
#       <td id="T_6499b_row0_col19" class="data row0 col19" >0.000000</td>
#       <td id="T_6499b_row0_col20" class="data row0 col20" >0.000000</td>
#       <td id="T_6499b_row0_col21" class="data row0 col21" >0.000000</td>
#       <td id="T_6499b_row0_col22" class="data row0 col22" >0.000000</td>
#       <td id="T_6499b_row0_col23" class="data row0 col23" >0.000000</td>
#       <td id="T_6499b_row0_col24" class="data row0 col24" >nan</td>
#       <td id="T_6499b_row0_col25" class="data row0 col25" >0.000000</td>
#       <td id="T_6499b_row0_col26" class="data row0 col26" >0.000000</td>
#       <td id="T_6499b_row0_col27" class="data row0 col27" >0.000000</td>
#       <td id="T_6499b_row0_col28" class="data row0 col28" >nan</td>
#       <td id="T_6499b_row0_col29" class="data row0 col29" >0.000000</td>
#       <td id="T_6499b_row0_col30" class="data row0 col30" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6499b_level0_row1" class="row_heading level0 row1" >Tower - Concrete</th>
#       <td id="T_6499b_row1_col0" class="data row1 col0" >inf</td>
#       <td id="T_6499b_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_6499b_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_6499b_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_6499b_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_6499b_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_6499b_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_6499b_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_6499b_row1_col8" class="data row1 col8" >0.000000</td>
#       <td id="T_6499b_row1_col9" class="data row1 col9" >0.000000</td>
#       <td id="T_6499b_row1_col10" class="data row1 col10" >0.000000</td>
#       <td id="T_6499b_row1_col11" class="data row1 col11" >12.601965</td>
#       <td id="T_6499b_row1_col12" class="data row1 col12" >inf</td>
#       <td id="T_6499b_row1_col13" class="data row1 col13" >1.4

# %%
vertical_scroll(empire_earth.units.relationships.matrices.matrix_strategic(units_paleo).style.set_sticky('columns'))
# Out:
# <div style='height: 500px; overflow: auto; width: fit-content'><style type="text/css">
# #T_546b9 thead tr:nth-child(1) th {
#   position: sticky;
#   background-color: white;
#   top: 0px;
#   z-index: 2;
#   height: 25px;
# }
# #T_546b9 thead tr:nth-child(2) th {
#   position: sticky;
#   background-color: white;
#   top: 25px;
#   z-index: 2;
#   height: 25px;
# }
# </style>
# <table id="T_546b9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_546b9_level0_col0" class="col_heading level0 col0" >88mm AA Gun</th>
#       <th id="T_546b9_level0_col1" class="col_heading level0 col1" >Tower - Concrete</th>
#       <th id="T_546b9_level0_col2" class="col_heading level0 col2" >Typhoon Anti-Tank</th>
#       <th id="T_546b9_level0_col3" class="col_heading level0 col3" >ME109  Fighter/Bomber</th>
#       <th id="T_546b9_level0_col4" class="col_heading level0 col4" >Spitfire Fighter</th>
#       <th id="T_546b9_level0_col5" class="col_heading level0 col5" >P-51 Fighter</th>
#       <th id="T_546b9_level0_col6" class="col_heading level0 col6" >ME262 Fighter/Bomber</th>
#       <th id="T_546b9_level0_col7" class="col_heading level0 col7" >Heinkel Bomber</th>
#       <th id="T_546b9_level0_col8" class="col_heading level0 col8" >B-17 Bomber</th>
#       <th id="T_546b9_level0_col9" class="col_heading level0 col9" >B-29 Bomber</th>
#       <th id="T_546b9_level0_col10" class="col_heading level0 col10" >Corsair Fighter/Bomber</th>
#       <th id="T_546b9_level0_col11" class="col_heading level0 col11" >Frigate - Warrington</th>
#       <th id="T_546b9_level0_col12" class="col_heading level0 col12" >Cruiser - Dardo</th>
#       <th id="T_546b9_level0_col13" class="col_heading level0 col13" >Battleship - Bismarck</th>
#       <th id="T_546b9_level0_col14" class="col_heading level0 col14" >Bazooka</th>
#       <th id="T_546b9_level0_col15" class="col_heading level0 col15" >Sniper</th>
#       <th id="T_546b9_level0_col16" class="col_heading level0 col16" >Trench Mortar</th>
#       <th id="T_546b9_level0_col17" class="col_heading level0 col17" >Flame Thrower</th>
#       <th id="T_546b9_level0_col18" class="col_heading level0 col18" >Machine Gun</th>
#       <th id="T_546b9_level0_col19" class="col_heading level0 col19" >Marine</th>
#       <th id="T_546b9_level0_col20" class="col_heading level0 col20" >SAS Commando</th>
#       <th id="T_546b9_level0_col21" class="col_heading level0 col21" >57mm AT Gun</th>
#       <th id="T_546b9_level0_col22" class="col_heading level0 col22" >Artillery</th>
#       <th id="T_546b9_level0_col23" class="col_heading level0 col23" >Howitzer Cannon</th>
#       <th id="T_546b9_level0_col24" class="col_heading level0 col24" >Flak Halftrack</th>
#       <th id="T_546b9_level0_col25" class="col_heading level0 col25" >Panzer Tank (AP)</th>
#       <th id="T_546b9_level0_col26" class="col_heading level0 col26" >Sherman Tank (HE)</th>
#       <th id="T_546b9_level0_col27" class="col_heading level0 col27" >Citizen</th>
#       <th id="T_546b9_level0_col28" class="col_heading level0 col28" >Sub - U-Boat</th>
#       <th id="T_546b9_level0_col29" class="col_heading level0 col29" >Erwin Rommel</th>
#       <th id="T_546b9_level0_col30" class="col_heading level0 col30" >Travis Shackelford</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Attacker</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#       <th class="blank col29" >&nbsp;</th>
#       <th class="blank col30" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_546b9_level0_row0" class="row_heading level0 row0" >88mm AA Gun</th>
#       <td id="T_546b9_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_546b9_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_546b9_row0_col2" class="data row0 col2" >inf</td>
#       <td id="T_546b9_row0_col3" class="data row0 col3" >9.115216</td>
#       <td id="T_546b9_row0_col4" class="data row0 col4" >inf</td>
#       <td id="T_546b9_row0_col5" class="data row0 col5" >inf</td>
#       <td id="T_546b9_row0_col6" class="data row0 col6" >6.555944</td>
#       <td id="T_546b9_row0_col7" class="data row0 col7" >0.234375</td>
#       <td id="T_546b9_row0_col8" class="data row0 col8" >0.173611</td>
#       <td id="T_546b9_row0_col9" class="data row0 col9" >0.079545</td>
#       <td id="T_546b9_row0_col10" class="data row0 col10" >8.591459</td>
#       <td id="T_546b9_row0_col11" class="data row0 col11" >0.000000</td>
#       <td id="T_546b9_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_546b9_row0_col13" class="data row0 col13" >0.000000</td>
#       <td id="T_546b9_row0_col14" class="data row0 col14" >0.000000</td>
#       <td id="T_546b9_row0_col15" class="data row0 col15" >0.000000</td>
#       <td id="T_546b9_row0_col16" class="data row0 col16" >0.000000</td>
#       <td id="T_546b9_row0_col17" class="data row0 col17" >0.000000</td>
#       <td id="T_546b9_row0_col18" class="data row0 col18" >0.000000</td>
#       <td id="T_546b9_row0_col19" class="data row0 col19" >0.000000</td>
#       <td id="T_546b9_row0_col20" class="data row0 col20" >0.000000</td>
#       <td id="T_546b9_row0_col21" class="data row0 col21" >0.000000</td>
#       <td id="T_546b9_row0_col22" class="data row0 col22" >0.000000</td>
#       <td id="T_546b9_row0_col23" class="data row0 col23" >0.000000</td>
#       <td id="T_546b9_row0_col24" class="data row0 col24" >nan</td>
#       <td id="T_546b9_row0_col25" class="data row0 col25" >0.000000</td>
#       <td id="T_546b9_row0_col26" class="data row0 col26" >0.000000</td>
#       <td id="T_546b9_row0_col27" class="data row0 col27" >0.000000</td>
#       <td id="T_546b9_row0_col28" class="data row0 col28" >nan</td>
#       <td id="T_546b9_row0_col29" class="data row0 col29" >0.000000</td>
#       <td id="T_546b9_row0_col30" class="data row0 col30" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_546b9_level0_row1" class="row_heading level0 row1" >Tower - Concrete</th>
#       <td id="T_546b9_row1_col0" class="data row1 col0" >inf</td>
#       <td id="T_546b9_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_546b9_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_546b9_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_546b9_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_546b9_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_546b9_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_546b9_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_546b9_row1_col8" class="data row1 col8" >0.000000</td>
#       <td id="T_546b9_row1_col9" class="data row1 col9" >0.000000</td>
#       <td id="T_546b9_row1_col10" class="data row1 col10" >0.000000</td>
#       <td id="T_546b9_row1_col11" class="data row1 col11" >18.002807</td>
#       <td id="T_546b9_row1_col12" class="data row1 col12" >inf</td>
#       <td id="T_546b9_row1_col13" class="data row1 col13" >4.28
